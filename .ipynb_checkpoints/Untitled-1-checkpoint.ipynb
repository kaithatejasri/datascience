# %%
import pandas as pd
data = {"players" :["vk","roh","sehwag","msd","vk","roh","seh","msd"],
    "matches" :[100,200,300,400,100,200,300,400],
    "total_runs" :[5000,8000,9000,7500,5200,8500,9200,7800],
    "highest_score":[183,264,219,183,160,209,201,150],
    "balls_faced" :[6000,9000,8500,8200,6100,9200,8600,8300]}
df = pd.DataFrame(data)
df["strikerate"] = (df["total_runs"]*df["balls_faced"])/100
print(df["strikerate"])
# Out:
# 0    300000.0
# 1    720000.0
# 2    765000.0
# 3    615000.0
# 4    317200.0
# 5    782000.0
# 6    791200.0
# 7    647400.0
# Name: strikerate, dtype: float64

# %%
import pandas as pd
data = {"players" :["vk","roh","sehwag","msd","vk","roh","seh","msd"],
    "matches" :[100,200,300,400,100,200,300,400],
    "total_runs" :[5000,8000,9000,7500,5200,8500,9200,7800],
    "highest_score":[183,264,219,183,160,209,201,150],
    "balls_faced" :[6000,9000,8500,8200,6100,9200,8600,8300]}
df = pd.DataFrame(data)
total =df.groupby("players")["total_runs"].sum().reset_index()
print(total)
# Out:
#   players  total_runs
# 0     msd       15300
# 1     roh       16500
# 2     seh        9200
# 3  sehwag        9000
# 4      vk       10200

# %%
import pandas as pd
data = {"players" :["vk","roh","sehwag","msd","vk","roh","seh","msd"],
    "matches" :[100,200,300,400,100,200,300,400],
    "total_runs" :[5000,8000,9000,7500,5200,8500,9200,7800],
    "highest_score":[183,264,219,183,160,209,201,150],
    "balls_faced" :[6000,9000,8500,8200,6100,9200,8600,8300]}
df = pd.DataFrame(data)
virat_kholi = df[(df["players"]=="vk") & (df["highest_score"]> 150)]
print(virat_kholi)
# Out:
#   players  matches  total_runs  highest_score  balls_faced
# 0      vk      100        5000            183         6000
# 4      vk      100        5200            160         6100

# %%
import pandas as pd
data = {
    "players" :["vk","roh","sehwag","msd","vk","roh","seh","msd"],
    "matches" :[100,200,300,400,100,200,300,400],
    "total_runs" :[5000,8000,9000,7500,5200,8500,9200,7800],
    "highest_score":[183,264,219,183,160,209,201,150],
    "balls_faced" :[6000,9000,8500,8200,6100,9200,8600,8300]
    
}
df = pd.DataFrame(data)
print(df)
# Out:
#   players  matches  total_runs  highest_score  balls_faced
# 0      vk      100        5000            183         6000
# 1     roh      200        8000            264         9000
# 2  sehwag      300        9000            219         8500
# 3     msd      400        7500            183         8200
# 4      vk      100        5200            160         6100
# 5     roh      200        8500            209         9200
# 6     seh      300        9200            201         8600
# 7     msd      400        7800            150         8300

# %%
print(df["players"])
# Out:
# 0        vk
# 1       roh
# 2    sehwag
# 3       msd
# 4        vk
# 5       roh
# 6       seh
# 7       msd
# Name: players, dtype: str
