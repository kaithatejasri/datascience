# %%
import pandas as pd
import numpy as np
data={"Name":["Rahul","Joy","Kumar","Mahi","Jhanvi","Shubham","Priya","Anit"],
      "Sal":[50000,60000,70000,80000,30000,32000,45000,87000],
      "Department":["IT","HR","Finance","IT","HR","Finance","IT","HR"],
      "City":["Mumbai","Delhi","Chicago","Kolkata","Hongkong","Delhi","Mumbai","Kolkata"],
      "Age":[25,30,35,40,50,21,43,45],
      "Experience":[4,7,0,0,2,8,3,5]}
df=pd.DataFrame(data)
print(df.loc[:,["Name","Sal"]])
# Out:
#       Name    Sal
# 0    Rahul  50000
# 1      Joy  60000
# 2    Kumar  70000
# 3     Mahi  80000
# 4   Jhanvi  30000
# 5  Shubham  32000
# 6    Priya  45000
# 7     Anit  87000

# %%
df.iloc[:,5]
# Out:
# 0    4
# 1    7
# 2    0
# 3    0
# 4    2
# 5    8
# 6    3
# 7    5
# Name: Experience, dtype: int64

# %%
print(df.iloc[:,5])
# Out:
# 0    4
# 1    7
# 2    0
# 3    0
# 4    2
# 5    8
# 6    3
# 7    5
# Name: Experience, dtype: int64

# %%
print(df.loc[:,["Name","Sal","Department","City","Age"]])
# Out:
#       Name    Sal Department      City  Age
# 0    Rahul  50000         IT    Mumbai   25
# 1      Joy  60000         HR     Delhi   30
# 2    Kumar  70000    Finance   Chicago   35
# 3     Mahi  80000         IT   Kolkata   40
# 4   Jhanvi  30000         HR  Hongkong   50
# 5  Shubham  32000    Finance     Delhi   21
# 6    Priya  45000         IT    Mumbai   43
# 7     Anit  87000         HR   Kolkata   45

# %%
df.iloc[:,5]
# Out:
# 0    4
# 1    7
# 2    0
# 3    0
# 4    2
# 5    8
# 6    3
# 7    5
# Name: Experience, dtype: int64

# %%
df.iloc[:,5]
# Out:
# 0    4
# 1    7
# 2    0
# 3    0
# 4    2
# 5    8
# 6    3
# 7    5
# Name: Experience, dtype: int64

# %%
df.iloc[:,2]
# Out:
# 0         IT
# 1         HR
# 2    Finance
# 3         IT
# 4         HR
# 5    Finance
# 6         IT
# 7         HR
# Name: Department, dtype: str

# %%
df.iloc[:0:3]
# Out:
# Empty DataFrame
# Columns: [Name, Sal, Department, City, Age, Experience]
# Index: []

# %%
df.iloc[:,[0,5]]
df.iloc[:,0:3]
# Out:
#       Name    Sal Department
# 0    Rahul  50000         IT
# 1      Joy  60000         HR
# 2    Kumar  70000    Finance
# 3     Mahi  80000         IT
# 4   Jhanvi  30000         HR
# 5  Shubham  32000    Finance
# 6    Priya  45000         IT
# 7     Anit  87000         HR

# %%
## here we are using .loc function to get rows+columns together

# %%
#syntax:df/loc[rows_selection,col_selection]
df.loc[0,"Name"]
# Out:
# 'Rahul'

# %%
df.loc[1,"Sal"]#here we are accessing specific row and specific col
#now multi rows and single col
df.loc[0:3,"Name"]
#multi col and multi row
df.loc[0:3,["Name","Age","Department"]]
# Out:
#     Name  Age Department
# 0  Rahul   25         IT
# 1    Joy   30         HR
# 2  Kumar   35    Finance
# 3   Mahi   40         IT

# %%
df.loc[df["Age"]>25,["Name","Sal","Age","Department"]]#simple way
# Out:
#      Name    Sal  Age Department
# 1     Joy  60000   30         HR
# 2   Kumar  70000   35    Finance
# 3    Mahi  80000   40         IT
# 4  Jhanvi  30000   50         HR
# 6   Priya  45000   43         IT
# 7    Anit  87000   45         HR

# %%
df.loc[0:3,["Name"]]#multi rows and single col
# Out:
#     Name
# 0  Rahul
# 1    Joy
# 2  Kumar
# 3   Mahi

# %%
mask=df["Age"]>25
df.loc[mask,["Name","Sal","Age","Department"]]#using mask
# Out:
#      Name    Sal  Age Department
# 1     Joy  60000   30         HR
# 2   Kumar  70000   35    Finance
# 3    Mahi  80000   40         IT
# 4  Jhanvi  30000   50         HR
# 6   Priya  45000   43         IT
# 7    Anit  87000   45         HR

# %%
df.loc[(df["Age"]>25) & (df["Sal"]>50000)],["Name","Sal","Age","Department"]#here we are using multi conditions
# this is doubtful
# Out:
# (    Name    Sal Department     City  Age  Experience
#  1    Joy  60000         HR    Delhi   30           7
#  2  Kumar  70000    Finance  Chicago   35           0
#  3   Mahi  80000         IT  Kolkata   40           0
#  7   Anit  87000         HR  Kolkata   45           5,
#  ['Name', 'Sal', 'Age', 'Department'])

# %%
#quer method  like sql

# %%
df.query("Age>25 and Sal>50000 and Department=='IT'")#this is query method to filter the data based on conditions
# Out:
#    Name    Sal Department     City  Age  Experience
# 3  Mahi  80000         IT  Kolkata   40           0

# %%
df.query("Age>25 and Sal>30000 and City in ['Chicago','Mumbai']")
# Out:
#     Name    Sal Department     City  Age  Experience
# 2  Kumar  70000    Finance  Chicago   35           0
# 6  Priya  45000         IT   Mumbai   43           3

# %%
con=30#here we have taken a var and we will use this in query method by using @symbol to refer the var
df.query("Age>@con and Sal>30000 and City in ['Chicago','Mumbai']")
# Out:
#     Name    Sal Department     City  Age  Experience
# 2  Kumar  70000    Finance  Chicago   35           0
# 6  Priya  45000         IT   Mumbai   43           3

# %% [markdown]
# #### isin() method this is like memebership method

# %%
df[df["City"].isin(["Delhi","Mumbai"])]
# Out:
#       Name    Sal Department    City  Age  Experience
# 0    Rahul  50000         IT  Mumbai   25           4
# 1      Joy  60000         HR   Delhi   30           7
# 5  Shubham  32000    Finance   Delhi   21           8
# 6    Priya  45000         IT  Mumbai   43           3

# %% [markdown]
# #between() - range checking

# %%
# age should be greater than 30 and less than 40
df[df["Age"].between(30,40)]#both ranges are inclusive
# Out:
#     Name    Sal Department     City  Age  Experience
# 1    Joy  60000         HR    Delhi   30           7
# 2  Kumar  70000    Finance  Chicago   35           0
# 3   Mahi  80000         IT  Kolkata   40           0

# %%
df[df["Age"].between(30,40)][["Name","Department"]]
# Out:
#     Name Department
# 1    Joy         HR
# 2  Kumar    Finance
# 3   Mahi         IT

# %% [markdown]
# #1.only to print sal and name cols
# #2.show the data whose age>40
# #3.display the row no 2 3 4 using .iloc()
# #4.show only first 4 rows of name and department columns
# #5.show all the names where department is it
# #6.show the first 3 cols of last 3 rows
# #7.show the data where sal is between 60k to 80k along with name and city col

# %%
df[["Name","Sal"]]
# Out:
#       Name    Sal
# 0    Rahul  50000
# 1      Joy  60000
# 2    Kumar  70000
# 3     Mahi  80000
# 4   Jhanvi  30000
# 5  Shubham  32000
# 6    Priya  45000
# 7     Anit  87000

# %%
df[df["Age"]>40]
# Out:
#      Name    Sal Department      City  Age  Experience
# 4  Jhanvi  30000         HR  Hongkong   50           2
# 6   Priya  45000         IT    Mumbai   43           3
# 7    Anit  87000         HR   Kolkata   45           5

# %%
df.iloc[2:5]
# Out:
#      Name    Sal Department      City  Age  Experience
# 2   Kumar  70000    Finance   Chicago   35           0
# 3    Mahi  80000         IT   Kolkata   40           0
# 4  Jhanvi  30000         HR  Hongkong   50           2

# %%
df.iloc[2:5, :]
# Out:
#      Name    Sal Department      City  Age  Experience
# 2   Kumar  70000    Finance   Chicago   35           0
# 3    Mahi  80000         IT   Kolkata   40           0
# 4  Jhanvi  30000         HR  Hongkong   50           2

# %%
df.loc[0:3,["Name","Department"]]
# Out:
#     Name Department
# 0  Rahul         IT
# 1    Joy         HR
# 2  Kumar    Finance
# 3   Mahi         IT

# %%
df[df["Department"]=="IT"]["Name"]
# Out:
# 0    Rahul
# 3     Mahi
# 6    Priya
# Name: Name, dtype: str

# %%
df[df["Department"].isin(["IT"])]["Name"]
# Out:
# 0    Rahul
# 3     Mahi
# 6    Priya
# Name: Name, dtype: str

# %%
df.iloc[-3:,0:3]
# Out:
#       Name    Sal Department
# 5  Shubham  32000    Finance
# 6    Priya  45000         IT
# 7     Anit  87000         HR

# %%
df.loc[(df["Sal"]>=60000)&(df["Sal"]<=80000,["Name","City"])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.loc[(df["Sal"]>=60000)&(df["Sal"]<=80000,["Name","City"])]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\arraylike.py:72, in OpsMixin.__and__(self, other)
#      70 @unpack_zerodim_and_defer("__and__")
#      71 def __and__(self, other):
# ---> 72     return self._logical_method(other, operator.and_)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:6746, in Series._logical_method(self, other, op)
#    6743 lvalues = self._values
#    6744 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6746 res_values = ops.logical_op(lvalues, rvalues, op)
#    6747 return self._construct_result(res_values, name=res_name, other=other)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\ops\array_ops.py:438, in logical_op(left, right, op)
#     435 right = lib.item_from_zerodim(right)
#     436 if is_list_like(right) and not hasattr(right, "dtype"):
#     437     # e.g. list, tuple
# --> 438     raise TypeError(
#     439         # GH#52264
#     440         "Logical ops (and, or, xor) between Pandas objects and dtype-less "
#     441         "sequences (e.g. list, tuple) are no longer supported. "
#     442         "Wrap the object in a Series, Index, or np.array "
#     443         "before operating instead.",
#     444     )
#     446 # NB: We assume extract_array has already been called on left and right
#     447 lvalues = ensure_wrapped_if_datetimelike(left)
#
# TypeError: Logical ops (and, or, xor) between Pandas objects and dtype-less sequences (e.g. list, tuple) are no longer supported. Wrap the object in a Series, Index, or np.array before operating instead.

# %%
df.loc[df["Sal"].between(60000, 80000), ["Name","City"]]

# %%
df.iloc[2:5]

# %% [markdown]
# #groupby()

# %%
df.groupby("City")['Sal'].mean()

# %%
df.groupby("Department")["Sal"].agg(['min','max','sum','count','mean'])

# %%
df.agg({'Age' : ['min','max','mean']})
# Out:
#          Age
# min   21.000
# max   50.000
# mean  36.125

# %%
df.agg({'Age' : ['min','max','mean'],
        'Sal' : ['min','max','std'],
        'Experience': ['min','max','median']})
# Out:
#            Age           Sal  Experience
# min     21.000  30000.000000         0.0
# max     50.000  87000.000000         8.0
# mean    36.125           NaN         NaN
# std        NaN  21224.985277         NaN
# median     NaN           NaN         3.5

# %% [markdown]
# ####sorting + EDA (Exploratory Data Analysis)

# %%
#sort_values() this is the functions to sort the things
#it has multiple params like by,ascending,inplace
df.sort_values("Experience")
# Out:
#       Name    Sal Department      City  Age  Experience
# 3     Mahi  80000         IT   Kolkata   40           0
# 2    Kumar  70000    Finance   Chicago   35           0
# 4   Jhanvi  30000         HR  Hongkong   50           2
# 6    Priya  45000         IT    Mumbai   43           3
# 0    Rahul  50000         IT    Mumbai   25           4
# 7     Anit  87000         HR   Kolkata   45           5
# 1      Joy  60000         HR     Delhi   30           7
# 5  Shubham  32000    Finance     Delhi   21           8

# %%
df.sort_values("Experience",ascending=False)
# Out:
#       Name    Sal Department      City  Age  Experience
# 5  Shubham  32000    Finance     Delhi   21           8
# 1      Joy  60000         HR     Delhi   30           7
# 7     Anit  87000         HR   Kolkata   45           5
# 0    Rahul  50000         IT    Mumbai   25           4
# 6    Priya  45000         IT    Mumbai   43           3
# 4   Jhanvi  30000         HR  Hongkong   50           2
# 3     Mahi  80000         IT   Kolkata   40           0
# 2    Kumar  70000    Finance   Chicago   35           0

# %%
df.sort_values("Name",ascending=False)
# Out:
#       Name    Sal Department      City  Age  Experience
# 5  Shubham  32000    Finance     Delhi   21           8
# 0    Rahul  50000         IT    Mumbai   25           4
# 6    Priya  45000         IT    Mumbai   43           3
# 3     Mahi  80000         IT   Kolkata   40           0
# 2    Kumar  70000    Finance   Chicago   35           0
# 1      Joy  60000         HR     Delhi   30           7
# 4   Jhanvi  30000         HR  Hongkong   50           2
# 7     Anit  87000         HR   Kolkata   45           5

# %%
df.sort_values(["Department","Sal"])
# Out:
#       Name    Sal Department      City  Age  Experience
# 5  Shubham  32000    Finance     Delhi   21           8
# 2    Kumar  70000    Finance   Chicago   35           0
# 4   Jhanvi  30000         HR  Hongkong   50           2
# 1      Joy  60000         HR     Delhi   30           7
# 7     Anit  87000         HR   Kolkata   45           5
# 6    Priya  45000         IT    Mumbai   43           3
# 0    Rahul  50000         IT    Mumbai   25           4
# 3     Mahi  80000         IT   Kolkata   40           0

# %%
df.sort_values(["Department","Sal"],ascending=[True,False])
# Out:
#       Name    Sal Department      City  Age  Experience
# 2    Kumar  70000    Finance   Chicago   35           0
# 5  Shubham  32000    Finance     Delhi   21           8
# 7     Anit  87000         HR   Kolkata   45           5
# 1      Joy  60000         HR     Delhi   30           7
# 4   Jhanvi  30000         HR  Hongkong   50           2
# 3     Mahi  80000         IT   Kolkata   40           0
# 0    Rahul  50000         IT    Mumbai   25           4
# 6    Priya  45000         IT    Mumbai   43           3

# %%
df['Sal_rank']=df['Sal'].rank()
df
# Out:
#       Name    Sal Department      City  Age  Experience  Sal_rank
# 0    Rahul  50000         IT    Mumbai   25           4       4.0
# 1      Joy  60000         HR     Delhi   30           7       5.0
# 2    Kumar  70000    Finance   Chicago   35           0       6.0
# 3     Mahi  80000         IT   Kolkata   40           0       7.0
# 4   Jhanvi  30000         HR  Hongkong   50           2       1.0
# 5  Shubham  32000    Finance     Delhi   21           8       2.0
# 6    Priya  45000         IT    Mumbai   43           3       3.0
# 7     Anit  87000         HR   Kolkata   45           5       8.0

# %%
df['Sal_rank']=df['Sal'].rank(ascending=False)
df
# Out:
#       Name    Sal Department      City  Age  Experience  Sal_rank
# 0    Rahul  50000         IT    Mumbai   25           4       5.0
# 1      Joy  60000         HR     Delhi   30           7       4.0
# 2    Kumar  70000    Finance   Chicago   35           0       3.0
# 3     Mahi  80000         IT   Kolkata   40           0       2.0
# 4   Jhanvi  30000         HR  Hongkong   50           2       8.0
# 5  Shubham  32000    Finance     Delhi   21           8       7.0
# 6    Priya  45000         IT    Mumbai   43           3       6.0
# 7     Anit  87000         HR   Kolkata   45           5       1.0

# %% [markdown]
# ####EDA-its the process to understand the data without assumptions

# %% [markdown]
# #### responsibility of analyst is to :
# 1.understand the data
# 2.find the pattern
# 3.find the problem in the data

# %%
df.head()#it will show first 5 rows of data by default
# Out:
#      Name    Sal Department      City  Age  Experience  Sal_rank
# 0   Rahul  50000         IT    Mumbai   25           4       5.0
# 1     Joy  60000         HR     Delhi   30           7       4.0
# 2   Kumar  70000    Finance   Chicago   35           0       3.0
# 3    Mahi  80000         IT   Kolkata   40           0       2.0
# 4  Jhanvi  30000         HR  Hongkong   50           2       8.0

# %%
df.tail()#it will  show last 5 rows of data by default
# Out:
#       Name    Sal Department      City  Age  Experience  Sal_rank
# 3     Mahi  80000         IT   Kolkata   40           0       2.0
# 4   Jhanvi  30000         HR  Hongkong   50           2       8.0
# 5  Shubham  32000    Finance     Delhi   21           8       7.0
# 6    Priya  45000         IT    Mumbai   43           3       6.0
# 7     Anit  87000         HR   Kolkata   45           5       1.0

# %%
df.sample(3)#it will return random 
df.sample(frac=0.5)
# Out:
#       Name    Sal Department     City  Age  Experience  Sal_rank
# 2    Kumar  70000    Finance  Chicago   35           0       3.0
# 5  Shubham  32000    Finance    Delhi   21           8       7.0
# 6    Priya  45000         IT   Mumbai   43           3       6.0
# 1      Joy  60000         HR    Delhi   30           7       4.0

# %%
df.shape#  gives no of rows and cols in tuple format
# Out:
# (8, 7)

# %%
df.info()# it will return
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      str
#  1   Sal         8 non-null      int64
#  2   Department  8 non-null      str
#  3   City        8 non-null      str
#  4   Age         8 non-null      int64
#  5   Experience  8 non-null      int64
#  6   Sal_rank    8 non-null      float64
# dtypes: float64(1), int64(3), str(3)
# memory usage: 580.0 bytes

# %%
df.dtypes
# Out:
# Name              str
# Sal             int64
# Department        str
# City              str
# Age             int64
# Experience      int64
# Sal_rank      float64
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.Series

# %%
num_cols=df.select_dtypes(include=['int64','float64']).columns
print(num_cols)
# Out:
# Index(['Sal', 'Age', 'Experience', 'Sal_rank'], dtype='str')

# %%
cat_col=df.select_dtypes(include=['object','string']).columns
print(cat_col)
# Out:
# Index(['Name', 'Department', 'City'], dtype='str')

# %%
print("Numerical columns:",len(list(num_cols)),"Categorical columns:",len(list(cat_col)))
type(num_cols)
# Out:
# Numerical columns: 4 Categorical columns: 3
# pandas.Index

# %%
df['Age']=df['Age']*1.0
df
# Out:
#       Name    Sal Department      City   Age  Experience  Sal_rank
# 0    Rahul  50000         IT    Mumbai  25.0           4       5.0
# 1      Joy  60000         HR     Delhi  30.0           7       4.0
# 2    Kumar  70000    Finance   Chicago  35.0           0       3.0
# 3     Mahi  80000         IT   Kolkata  40.0           0       2.0
# 4   Jhanvi  30000         HR  Hongkong  50.0           2       8.0
# 5  Shubham  32000    Finance     Delhi  21.0           8       7.0
# 6    Priya  45000         IT    Mumbai  43.0           3       6.0
# 7     Anit  87000         HR   Kolkata  45.0           5       1.0

# %%
num_cols=df.select_dtypes(include=['int64','float64']).columns
print(num_cols)
cat_col=df.select_dtypes(include=['object','string']).columns
print(cat_col)
print("Numerical columns:",len(list(num_cols)),"Categorical columns:",len(list(cat_col)))
type(num_cols)
# Out:
# Index(['Sal', 'Age', 'Experience', 'Sal_rank'], dtype='str')
# Index(['Name', 'Department', 'City'], dtype='str')
# Numerical columns: 4 Categorical columns: 3
# pandas.Index

# %%
df['Age']=df['Age']*1.0
df['Age']=df['Age']## inka edho cheparuuu...

# %%
df.describe()
# Out:
#                 Sal        Age  Experience  Sal_rank
# count      8.000000   8.000000    8.000000   8.00000
# mean   56750.000000  36.125000    3.625000   4.50000
# std    21224.985277  10.176128    2.973094   2.44949
# min    30000.000000  21.000000    0.000000   1.00000
# 25%    41750.000000  28.750000    1.500000   2.75000
# 50%    55000.000000  37.500000    3.500000   4.50000
# 75%    72500.000000  43.500000    5.500000   6.25000
# max    87000.000000  50.000000    8.000000   8.00000

# %%
df['Sal'].mean()
# Out:
# np.float64(56750.0)

# %%
df['Sal'].agg(['min','max','mean','std'])
# Out:
# min     30000.000000
# max     87000.000000
# mean    56750.000000
# std     21224.985277
# Name: Sal, dtype: float64

# %%
df['Experience'].agg(['min','max','mean','std'])
# Out:
# min     0.000000
# max     8.000000
# mean    3.625000
# std     2.973094
# Name: Experience, dtype: float64

# %%
df.describe(include=("object","string"))
# Out:
#          Name Department    City
# count       8          8       8
# unique      8          3       5
# top     Rahul         IT  Mumbai
# freq        1          3       2

# %%
df.describe(include="all")
# Out:
#          Name           Sal Department    City        Age  Experience  \
# count       8      8.000000          8       8   8.000000    8.000000
# unique      8           NaN          3       5        NaN         NaN
# top     Rahul           NaN         IT  Mumbai        NaN         NaN
# freq        1           NaN          3       2        NaN         NaN
# mean      NaN  56750.000000        NaN     NaN  36.125000    3.625000
# std       NaN  21224.985277        NaN     NaN  10.176128    2.973094
# min       NaN  30000.000000        NaN     NaN  21.000000    0.000000
# 25%       NaN  41750.000000        NaN     NaN  28.750000    1.500000
# 50%       NaN  55000.000000        NaN     NaN  37.500000    3.500000
# 75%       NaN  72500.000000        NaN     NaN  43.500000    5.500000
# max       NaN  87000.000000        NaN     NaN  50.000000    8.000000
#
#         Sal_rank
# count    8.00000
# unique       NaN
# top          NaN
# freq         NaN
# mean     4.50000
# std      2.44949
# min      1.00000
# 25%      2.75000
# 50%      4.50000
# 75%      6.25000
# max      8.00000

# %%
City_count=df['City'].value_counts()
City_count
# Out:
# City
# Mumbai      2
# Delhi       2
# Kolkata     2
# Chicago     1
# Hongkong    1
# Name: count, dtype: int64

# %%
City_count=df['City'].value_counts(normalize=True)*100
City_count
# Out:
# City
# Mumbai      25.0
# Delhi       25.0
# Kolkata     25.0
# Chicago     12.5
# Hongkong    12.5
# Name: proportion, dtype: float64
