# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({
    "Name":["Rahul","Joy","Kumar","Mahi","Jhanvi","Shubham","Priya","Anit"],
    "Age":[25,np.nan,35,40,50,np.nan,43,45],
    "City":["mumbai","delhi","chicago","kolkata","np.nan","hongkong","delhi","kolkata"],
    "Sal":[50000,60000,70000,80000,30000,32000,45000,87000],
    "Experience":[2,5,7,np.nan,15,1,8,np.nan],
    "Department":["IT","HR","Finance",np.nan,"HR","Finance","IT","HR"]
})
df
# Out:
#       Name   Age      City    Sal  Experience Department
# 0    Rahul  25.0    mumbai  50000         2.0         IT
# 1      Joy   NaN     delhi  60000         5.0         HR
# 2    Kumar  35.0   chicago  70000         7.0    Finance
# 3     Mahi  40.0   kolkata  80000         NaN        NaN
# 4   Jhanvi  50.0    np.nan  30000        15.0         HR
# 5  Shubham   NaN  hongkong  32000         1.0    Finance
# 6    Priya  43.0     delhi  45000         8.0         IT
# 7     Anit  45.0   kolkata  87000         NaN         HR

# %%
df.isna()
# Out:
#     Name    Age   City    Sal  Experience  Department
# 0  False  False  False  False       False       False
# 1  False   True  False  False       False       False
# 2  False  False  False  False       False       False
# 3  False  False  False  False        True        True
# 4  False  False  False  False       False       False
# 5  False   True  False  False       False       False
# 6  False  False  False  False       False       False
# 7  False  False  False  False        True       False

# %%
df.isna().sum()
# Out:
# Name          0
# Age           2
# City          0
# Sal           0
# Experience    2
# Department    1
# dtype: int64

# %%
df.isnull()
# Out:
#     Name    Age   City    Sal  Experience  Department
# 0  False  False  False  False       False       False
# 1  False   True  False  False       False       False
# 2  False  False  False  False       False       False
# 3  False  False  False  False        True        True
# 4  False  False  False  False       False       False
# 5  False   True  False  False       False       False
# 6  False  False  False  False       False       False
# 7  False  False  False  False        True       False

# %%
df.notna()
# Out:
#    Name    Age  City   Sal  Experience  Department
# 0  True   True  True  True        True        True
# 1  True  False  True  True        True        True
# 2  True   True  True  True        True        True
# 3  True   True  True  True       False       False
# 4  True   True  True  True        True        True
# 5  True  False  True  True        True        True
# 6  True   True  True  True        True        True
# 7  True   True  True  True       False        True

# %%
df.notnull().sum()
# Out:
# Name          8
# Age           6
# City          8
# Sal           8
# Experience    6
# Department    7
# dtype: int64

# %%
len(df)
# Out:
# 8

# %%
df.isna()
# Out:
#     Name    Age   City    Sal  Experience  Department
# 0  False  False  False  False       False       False
# 1  False   True  False  False       False       False
# 2  False  False  False  False       False       False
# 3  False  False  False  False        True        True
# 4  False  False  False  False       False       False
# 5  False   True  False  False       False       False
# 6  False  False  False  False       False       False
# 7  False  False  False  False        True       False

# %%
df.isna().sum()#it will  return count of missing values in each col of data frame
# Out:
# Name          0
# Age           2
# City          0
# Sal           0
# Experience    2
# Department    1
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# Name           0.0
# Age           25.0
# City           0.0
# Sal            0.0
# Experience    25.0
# Department    12.5
# dtype: float64

# %%
df[df.isna().any(axis=1)]#it will return the rows which have at least one missing value in any column
# Out:
#       Name   Age     City    Sal  Experience Department
# 1      Joy   NaN    delhi  60000         5.0         HR
# 3     Mahi  40.0  kolkata  80000         NaN        NaN
# 5  Shubham   NaN    delhi  32000         1.0    Finance
# 7     Anit  45.0  kolkata  87000         NaN         HR

# %%
df[df["Name"].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, Age, City, Sal, Experience, Department]
# Index: []

# %%
df[df.isna().all(axis=1)]#it will return the rows which have at least one missing value in any column
# Out:
# Empty DataFrame
# Columns: [Name, Age, City, Sal, Experience, Department]
# Index: []

# %%
df[df.isna().all(axis=1)]
df[df.isna().any(axis=1)]
# Out:
#       Name   Age     City    Sal  Experience Department
# 1      Joy   NaN    delhi  60000         5.0         HR
# 3     Mahi  40.0  kolkata  80000         NaN        NaN
# 5  Shubham   NaN    delhi  32000         1.0    Finance
# 7     Anit  45.0  kolkata  87000         NaN         HR

# %%
df[df["Age"].isna()]
# Out:
#       Name  Age   City    Sal  Experience Department
# 1      Joy  NaN  delhi  60000         5.0         HR
# 5  Shubham  NaN  delhi  32000         1.0    Finance

# %%
df.dropna(subset=["Age"])#this will drop the rows which have missing values in the age col only
# Out:
#      Name   Age      City    Sal  Experience Department
# 0   Rahul  25.0    mumbai  50000         2.0         IT
# 2   Kumar  35.0   chicago  70000         7.0    Finance
# 3    Mahi  40.0   kolkata  80000         NaN        NaN
# 4  Jhanvi  50.0  hongkong  30000        15.0         HR
# 6   Priya  43.0    np.nan  45000         8.0         IT
# 7    Anit  45.0   kolkata  87000         NaN         HR

# %%
#df.dropna(subset=["Experience"])#it will drop the rows which have missing values in experience col
# Out:
#       Name   Age      City    Sal  Experience Department
# 0    Rahul  25.0    mumbai  50000         2.0         IT
# 1      Joy   NaN     delhi  60000         5.0         HR
# 2    Kumar  35.0   chicago  70000         7.0    Finance
# 4   Jhanvi  50.0  hongkong  30000        15.0         HR
# 5  Shubham   NaN     delhi  32000         1.0    Finance
# 6    Priya  43.0    np.nan  45000         8.0         IT

# %%
#df.dropna(subset=["Experience","Age","City"])
# Out:
#      Name   Age     City    Sal  Experience Department
# 0   Rahul  25.0   mumbai  50000         2.0         IT
# 2   Kumar  35.0  chicago  70000         7.0    Finance
# 4  Jhanvi  50.0   np.nan  30000        15.0         HR
# 6   Priya  43.0    delhi  45000         8.0         IT

# %%
#df.dropna(axis=1)
# Out:
#      Name   Age     City    Sal  Experience Department
# 0   Rahul  25.0   mumbai  50000         2.0         IT
# 2   Kumar  35.0  chicago  70000         7.0    Finance
# 4  Jhanvi  50.0   np.nan  30000        15.0         HR
# 6   Priya  43.0    delhi  45000         8.0         IT

# %%
#df2=df.dropna(axis=1)
#df2
# Out:
#      Name   Age     City    Sal  Experience Department
# 0   Rahul  25.0   mumbai  50000         2.0         IT
# 2   Kumar  35.0  chicago  70000         7.0    Finance
# 4  Jhanvi  50.0   np.nan  30000        15.0         HR
# 6   Priya  43.0    delhi  45000         8.0         IT

# %%
#df["Experience"].fillna(0)
# Out:
# 0     2.0
# 2     7.0
# 4    15.0
# 6     8.0
# Name: Experience, dtype: float64

# %%
df
# Out:
#      Name   Age     City    Sal  Experience Department
# 0   Rahul  25.0   mumbai  50000         2.0         IT
# 2   Kumar  35.0  chicago  70000         7.0    Finance
# 4  Jhanvi  50.0   np.nan  30000        15.0         HR
# 6   Priya  43.0    delhi  45000         8.0         IT

# %%
# Out:
#      Name   Age     City    Sal  Experience Department
# 0   Rahul  25.0   mumbai  50000         2.0         IT
# 2   Kumar  35.0  chicago  70000         7.0    Finance
# 4  Jhanvi  50.0   np.nan  30000        15.0         HR
# 6   Priya  43.0    delhi  45000         8.0         IT

# %%
df=pd.DataFrame({
    "Name":["Rahul","Joy","Kumar","Mahi","Jhanvi","Shubham","Priya","Anit"],
    "Age":[25,np.nan,35,40,50,np.nan,43,45],
    "City":["mumbai","delhi","chicago","kolkata",np.nan,"hongkong","delhi","kolkata"],
    "Sal":[50000,60000,70000,80000,30000,32000,45000,87000],
    "Experience":[2,5,7,np.nan,15,1,8,np.nan],
    "Department":["IT","HR","Finance",np.nan,"HR","Finance","IT","HR"]
})
df
# Out:
#       Name   Age      City    Sal  Experience Department
# 0    Rahul  25.0    mumbai  50000         2.0         IT
# 1      Joy   NaN     delhi  60000         5.0         HR
# 2    Kumar  35.0   chicago  70000         7.0    Finance
# 3     Mahi  40.0   kolkata  80000         NaN        NaN
# 4   Jhanvi  50.0       NaN  30000        15.0         HR
# 5  Shubham   NaN  hongkong  32000         1.0    Finance
# 6    Priya  43.0     delhi  45000         8.0         IT
# 7     Anit  45.0   kolkata  87000         NaN         HR

# %%
df["Experience"].fillna(0)
# Out:
# 0     2.0
# 1     5.0
# 2     7.0
# 3     0.0
# 4    15.0
# 5     1.0
# 6     8.0
# 7     0.0
# Name: Experience, dtype: float64

# %%
df["City"].fillna("unknown")
# Out:
# 0      mumbai
# 1       delhi
# 2     chicago
# 3     kolkata
# 4      np.nan
# 5    hongkong
# 6       delhi
# 7     kolkata
# Name: City, dtype: str

# %%
df["City"].fillna("NA")#unknown and NA are same
# Out:
# 0      mumbai
# 1       delhi
# 2     chicago
# 3     kolkata
# 4      np.nan
# 5    hongkong
# 6       delhi
# 7     kolkata
# Name: City, dtype: str

# %%
df.fillna({"Experience":0,"City":"unknown"})
# Out:
#       Name   Age      City    Sal  Experience Department
# 0    Rahul  25.0    mumbai  50000         2.0         IT
# 1      Joy   NaN     delhi  60000         5.0         HR
# 2    Kumar  35.0   chicago  70000         7.0    Finance
# 3     Mahi  40.0   kolkata  80000         0.0        NaN
# 4   Jhanvi  50.0    np.nan  30000        15.0         HR
# 5  Shubham   NaN  hongkong  32000         1.0    Finance
# 6    Priya  43.0     delhi  45000         8.0         IT
# 7     Anit  45.0   kolkata  87000         0.0         HR

# %% [markdown]
# Filling empty values Statistically

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0    25.000000
# 1    39.666667
# 2    35.000000
# 3    40.000000
# 4    50.000000
# 5    39.666667
# 6    43.000000
# 7    45.000000
# Name: Age, dtype: float64

# %%
df["Age"].fillna(df["Age"].median())
# Out:
# 0    25.0
# 1    41.5
# 2    35.0
# 3    40.0
# 4    50.0
# 5    41.5
# 6    43.0
# 7    45.0
# Name: Age, dtype: float64

# %%
df["Experience"].fillna(df["Experience"].mean())
# Out:
# 0     2.000000
# 1     5.000000
# 2     7.000000
# 3     6.333333
# 4    15.000000
# 5     1.000000
# 6     8.000000
# 7     6.333333
# Name: Experience, dtype: float64

# %%
df["City"].fillna(df["City"].mode()[1])
# Out:
# 0      mumbai
# 1       delhi
# 2     chicago
# 3     kolkata
# 4      np.nan
# 5    hongkong
# 6       delhi
# 7     kolkata
# Name: City, dtype: str

# %%
df
# Out:
#       Name   Age      City    Sal  Experience Department
# 0    Rahul  25.0    mumbai  50000         2.0         IT
# 1      Joy   NaN     delhi  60000         5.0         HR
# 2    Kumar  35.0   chicago  70000         7.0    Finance
# 3     Mahi  40.0   kolkata  80000         NaN        NaN
# 4   Jhanvi  50.0       NaN  30000        15.0         HR
# 5  Shubham   NaN  hongkong  32000         1.0    Finance
# 6    Priya  43.0     delhi  45000         8.0         IT
# 7     Anit  45.0   kolkata  87000         NaN         HR

# %%
df["City"].fillna(df["City"].mode()[0])
# Out:
# 0      mumbai
# 1       delhi
# 2     chicago
# 3     kolkata
# 4       delhi
# 5    hongkong
# 6       delhi
# 7     kolkata
# Name: City, dtype: str

# %%
df["Department"].fillna(df["Department"].mode()[0])
# Out:
# 0         IT
# 1         HR
# 2    Finance
# 3         HR
# 4         HR
# 5    Finance
# 6         IT
# 7         HR
# Name: Department, dtype: str

# %% [markdown]
# Replace

# %%
df.replace("Finance","Fina",inplace=True)
df
# Out:
#       Name   Age      City    Sal  Experience Department
# 0    Rahul  25.0    mumbai  50000         2.0         IT
# 1      Joy   NaN     delhi  60000         5.0         HR
# 2    Kumar  35.0   chicago  70000         7.0       Fina
# 3     Mahi  40.0   kolkata  80000         NaN        NaN
# 4   Jhanvi  50.0       NaN  30000        15.0         HR
# 5  Shubham   NaN  hongkong  32000         1.0       Fina
# 6    Priya  43.0     delhi  45000         8.0         IT
# 7     Anit  45.0   kolkata  87000         NaN         HR

# %%
# Out:
#       Name   Age      City    Sal Experience Department
# 0    Rahul  25.0    mumbai  50000        2.0         IT
# 1      Joy  Fina     delhi  60000        5.0         HR
# 2    Kumar  35.0   chicago  70000        7.0       Fina
# 3     Mahi  40.0   kolkata  80000       Fina       Fina
# 4   Jhanvi  50.0      Fina  30000       15.0         HR
# 5  Shubham  Fina  hongkong  32000        1.0       Fina
# 6    Priya  43.0     delhi  45000        8.0         IT
# 7     Anit  45.0   kolkata  87000       Fina         HR

# %%
df=pd.DataFrame({
    "Name":["Rahul","Joy","Kumar","Mahi","Jhanvi","Shubham","Priya","Anit"],
    "Age":[25,np.nan,35,40,50,np.nan,43,45],
    "City":["mumbai","delhi","chicago","kolkata",np.nan,"hongkong","delhi","kolkata"],
    "Sal":[50000,60000,70000,80000,30000,32000,45000,87000],
    "Experience":[2,5,7,np.nan,15,1,8,np.nan],
    "Department":["IT","HR","Finance",np.nan,"HR","Finance","IT","HR"]
})
df
# Out:
#       Name   Age      City    Sal  Experience Department
# 0    Rahul  25.0    mumbai  50000         2.0         IT
# 1      Joy   NaN     delhi  60000         5.0         HR
# 2    Kumar  35.0   chicago  70000         7.0    Finance
# 3     Mahi  40.0   kolkata  80000         NaN        NaN
# 4   Jhanvi  50.0       NaN  30000        15.0         HR
# 5  Shubham   NaN  hongkong  32000         1.0    Finance
# 6    Priya  43.0     delhi  45000         8.0         IT
# 7     Anit  45.0   kolkata  87000         NaN         HR

# %%
data=pd.DataFrame({
    "Student":["Alice","Bob","Charlie","David","rohit","agastya","amar","joy"],
    "maths":[85,90,np.nan,92,88,95,80,91],
    "science":[80,85,90,np.nan,88,92,np.nan,89],
    "English":[75,80,85,90,88,92,84,89],
    "Sanskrit":[70,75,np.nan,85,88,90,82,87],
    "Attendance":[90,85,95,80,88,np.nan,84,89]
})
data
# Out:
#    Student  maths  science  English  Sanskrit  Attendance
# 0    Alice   85.0     80.0       75      70.0        90.0
# 1      Bob   90.0     85.0       80      75.0        85.0
# 2  Charlie    NaN     90.0       85       NaN        95.0
# 3    David   92.0      NaN       90      85.0        80.0
# 4    rohit   88.0     88.0       88      88.0        88.0
# 5  agastya   95.0     92.0       92      90.0         NaN
# 6     amar   80.0      NaN       84      82.0        84.0
# 7      joy   91.0     89.0       89      87.0        89.0

# %% [markdown]
# Task
# 1. count the missing values
# 2. Fill all missing values in maths with mean value without using mean function
# 3. in english fill missing values with 0
# 4. verify whether your data is having any missing values or not
# 5. fill nan values in attendance column using mean value
# 6. remove that row which have more than 2 nan values

# %%
data.isnull().sum()
# Out:
# Student       0
# maths         1
# science       2
# English       0
# Sanskrit      1
# Attendance    1
# dtype: int64

# %%
mean = data['maths'].sum() / data['maths'].count()
data['maths'] = data['maths'].fillna(mean)
data
# Out:
#    Student      maths  science  English  Sanskrit  Attendance
# 0    Alice  85.000000     80.0       75      70.0        90.0
# 1      Bob  90.000000     85.0       80      75.0        85.0
# 2  Charlie  88.714286     90.0       85       NaN        95.0
# 3    David  92.000000      NaN       90      85.0        80.0
# 4    rohit  88.000000     88.0       88      88.0        88.0
# 5  agastya  95.000000     92.0       92      90.0         NaN
# 6     amar  80.000000      NaN       84      82.0        84.0
# 7      joy  91.000000     89.0       89      87.0        89.0

# %%
data['English'] = data['English'].fillna(0)
data
# Out:
#    Student      maths  science  English  Sanskrit  Attendance
# 0    Alice  85.000000     80.0       75      70.0        90.0
# 1      Bob  90.000000     85.0       80      75.0        85.0
# 2  Charlie  88.714286     90.0       85       NaN        95.0
# 3    David  92.000000      NaN       90      85.0        80.0
# 4    rohit  88.000000     88.0       88      88.0        88.0
# 5  agastya  95.000000     92.0       92      90.0         NaN
# 6     amar  80.000000      NaN       84      82.0        84.0
# 7      joy  91.000000     89.0       89      87.0        89.0

# %%
data.isnull().sum()
# Out:
# Student       0
# maths         0
# science       2
# English       0
# Sanskrit      1
# Attendance    1
# dtype: int64

# %%
mean = data['Attendance'].sum() / data['Attendance'].count()
data['Attendance'] = data['Attendance'].fillna(mean)
data
# Out:
#    Student      maths  science  English  Sanskrit  Attendance
# 0    Alice  85.000000     80.0       75      70.0   90.000000
# 1      Bob  90.000000     85.0       80      75.0   85.000000
# 2  Charlie  88.714286     90.0       85       NaN   95.000000
# 3    David  92.000000      NaN       90      85.0   80.000000
# 4    rohit  88.000000     88.0       88      88.0   88.000000
# 5  agastya  95.000000     92.0       92      90.0   87.285714
# 6     amar  80.000000      NaN       84      82.0   84.000000
# 7      joy  91.000000     89.0       89      87.0   89.000000
