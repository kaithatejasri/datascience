# %%
import pandas as pd 
import numpy as np 
df=pd.DataFrame({
    "Name":["Rahul","Joy","Kumar","Mahi","Jhanvi","Shubham","Priya","Anit"],
     "age":[25,30,35,40,50,21,43,45],
     "city":["mumbai","delhi","Chicago","kolkata","hongkong","delhi","mumbai","kolkata"],
     "sal":[50000,60000,70000,80000,30000,32000,45000,870000],
     "Experience":[2,5,7,10,15,1,8,20],
     "Department":["IT","HR","Finance","IT","HR","Finance","IT","HR"]
})
df
# Out:
#       Name  age      city     sal  Experience Department
# 0    Rahul   25    mumbai   50000           2         IT
# 1      Joy   30     delhi   60000           5         HR
# 2    Kumar   35   Chicago   70000           7    Finance
# 3     Mahi   40   kolkata   80000          10         IT
# 4   Jhanvi   50  hongkong   30000          15         HR
# 5  Shubham   21     delhi   32000           1    Finance
# 6    Priya   43    mumbai   45000           8         IT
# 7     Anit   45   kolkata  870000          20         HR

# %%
df["Department"]   # Both will return the Same Thing a single columns data
# Out:
# 0         IT
# 1         HR
# 2    Finance
# 3         IT
# 4         HR
# 5    Finance
# 6         IT
# 7         HR
# Name: Department, dtype: str

# %%
df.Department # this will also return the same thing that is the single column data
# Out:
# 0         IT
# 1         HR
# 2    Finance
# 3         IT
# 4         HR
# 5    Finance
# 6         IT
# 7         HR
# Name: Department, dtype: str

# %%
print(type(df["Name"]))  # This will return the Series
# Out:
# <class 'pandas.Series'>

# %%
print(type(df[["Name"]])) # This will return the DataFrame
# Out:
# <class 'pandas.DataFrame'>

# %%
df.loc[:,["Name","sal"]] # This will return DataFrame
# Out:
#       Name     sal
# 0    Rahul   50000
# 1      Joy   60000
# 2    Kumar   70000
# 3     Mahi   80000
# 4   Jhanvi   30000
# 5  Shubham   32000
# 6    Priya   45000
# 7     Anit  870000

# %%
df[["Name","sal"]]
# Out:
#       Name     sal
# 0    Rahul   50000
# 1      Joy   60000
# 2    Kumar   70000
# 3     Mahi   80000
# 4   Jhanvi   30000
# 5  Shubham   32000
# 6    Priya   45000
# 7     Anit  870000

# %%
# This is Column Access or can sal Label based Access 
df.iloc[:,[0,5]] # This will return Name and Department
# Out:
#       Name Department
# 0    Rahul         IT
# 1      Joy         HR
# 2    Kumar    Finance
# 3     Mahi         IT
# 4   Jhanvi         HR
# 5  Shubham    Finance
# 6    Priya         IT
# 7     Anit         HR

# %%
df.iloc[:,0:5]
# Out:
#       Name  age      city     sal  Experience
# 0    Rahul   25    mumbai   50000           2
# 1      Joy   30     delhi   60000           5
# 2    Kumar   35   Chicago   70000           7
# 3     Mahi   40   kolkata   80000          10
# 4   Jhanvi   50  hongkong   30000          15
# 5  Shubham   21     delhi   32000           1
# 6    Priya   43    mumbai   45000           8
# 7     Anit   45   kolkata  870000          20

# %%
df.iloc[:,0:3] # This will three coluns Name age and City in dataFrame format
# Out:
#       Name  age      city
# 0    Rahul   25    mumbai
# 1      Joy   30     delhi
# 2    Kumar   35   Chicago
# 3     Mahi   40   kolkata
# 4   Jhanvi   50  hongkong
# 5  Shubham   21     delhi
# 6    Priya   43    mumbai
# 7     Anit   45   kolkata

# %% [markdown]
# ### Now we are going to access rows Using .iloc method

# %%
print(df.iloc[[4,2]])
# Out:
#      Name  age      city    sal  Experience Department
# 4  Jhanvi   50  hongkong  30000          15         HR
# 2   Kumar   35   Chicago  70000           7    Finance

# %%
df.iloc[0:3,0:4]
# Out:
#     Name  age     city    sal
# 0  Rahul   25   mumbai  50000
# 1    Joy   30    delhi  60000
# 2  Kumar   35  Chicago  70000

# %%
df.iloc[[4]]
# Out:
#      Name  age      city    sal  Experience Department
# 4  Jhanvi   50  hongkong  30000          15         HR

# %% [markdown]
# ##### I want to print 0th and 1st row and 0th and 3rd column what should i write to get it printed

# %%
df.iloc[[0,1],[0,3]]
# Out:
#     Name    sal
# 0  Rahul  50000
# 1    Joy  60000

# %% [markdown]
# #### We are Going to Use .loc function to get the rows printed

# %%
print(df.loc[[0,2,3]])
# Out:
#     Name  age     city    sal  Experience Department
# 0  Rahul   25   mumbai  50000           2         IT
# 2  Kumar   35  Chicago  70000           7    Finance
# 3   Mahi   40  kolkata  80000          10         IT

# %%
print("Second output")
# Out:
# Second output

# %%
print(df.loc[3])
# Out:
# Name             Mahi
# age                40
# city          kolkata
# sal             80000
# Experience         10
# Department         IT
# Name: 3, dtype: object

# %%
df.loc[3]
# Out:
# Name             Mahi
# age                40
# city          kolkata
# sal             80000
# Experience         10
# Department         IT
# Name: 3, dtype: object

# %%
df2=df.set_index("Name")
df2
# Out:
#          age      city     sal  Experience Department
# Name
# Rahul     25    mumbai   50000           2         IT
# Joy       30     delhi   60000           5         HR
# Kumar     35   Chicago   70000           7    Finance
# Mahi      40   kolkata   80000          10         IT
# Jhanvi    50  hongkong   30000          15         HR
# Shubham   21     delhi   32000           1    Finance
# Priya     43    mumbai   45000           8         IT
# Anit      45   kolkata  870000          20         HR

# %%
df2.loc[["Jhanvi","Priya"]]
# Out:
#         age      city    sal  Experience Department
# Name
# Jhanvi   50  hongkong  30000          15         HR
# Priya    43    mumbai  45000           8         IT

# %% [markdown]
# #### Here we are going to Use .loc function to get rows+columns together
#
# # Syntax  : df.loc[rows_selection,col_selection]

# %%
print(df.loc[3,"sal"])  # here we are accessing specific row and specific col
# Out:
# 80000

# %%
# Now multiple rows  and multiple column
df.loc[0:3,["Name","age","Department"]]
# Out:
#     Name  age Department
# 0  Rahul   25         IT
# 1    Joy   30         HR
# 2  Kumar   35    Finance
# 3   Mahi   40         IT

# %%
df.loc[df["age"]>25,["Name","sal","age","Department"]]# simple way
# Out:
#      Name     sal  age Department
# 1     Joy   60000   30         HR
# 2   Kumar   70000   35    Finance
# 3    Mahi   80000   40         IT
# 4  Jhanvi   30000   50         HR
# 6   Priya   45000   43         IT
# 7    Anit  870000   45         HR

# %%
print(df["age"]>25,["Name","sal","age","Department"])
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# Name: age, dtype: bool ['Name', 'sal', 'age', 'Department']

# %%
mask=df["age"]>25
df.loc[mask,["Name","sal","age","Department"]] # here we are using Masking
# Out:
#      Name     sal  age Department
# 1     Joy   60000   30         HR
# 2   Kumar   70000   35    Finance
# 3    Mahi   80000   40         IT
# 4  Jhanvi   30000   50         HR
# 6   Priya   45000   43         IT
# 7    Anit  870000   45         HR

# %%
df[(df["age"]>25) & (df["sal"]>50000)],[["Name","sal","age","Department"] ]# here we are using multiple conditions
# This is doubtful syntax but it is correct and it will work fin
# Out:
# (    Name  age     city     sal  Experience Department
#  1    Joy   30    delhi   60000           5         HR
#  2  Kumar   35  Chicago   70000           7    Finance
#  3   Mahi   40  kolkata   80000          10         IT
#  7   Anit   45  kolkata  870000          20         HR,
#  [['Name', 'sal', 'age', 'Department']])

# %% [markdown]
# #### Query method like sql

# %%
df.query("(age>25) and (sal>50000) and (Department=='IT')") # this is query method to filter the data based on conditions
# Out:
#    Name  age     city    sal  Experience Department
# 3  Mahi   40  kolkata  80000          10         IT

# %%
df.query("age>25 and sal>50000 and Department=='IT'") # this is query method to filter the data based on conditions
# Out:
#    Name  age     city    sal  Experience Department
# 3  Mahi   40  kolkata  80000          10         IT

# %%
df.query("age>25 and sal>30000 and city in ['Chicago','mumbai']")
# Out:
#     Name  age     city    sal  Experience Department
# 2  Kumar   35  Chicago  70000           7    Finance
# 6  Priya   43   mumbai  45000           8         IT

# %% [markdown]
# @var way to write the queries
