# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("fueldata.csv")
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# 1              M6         Z                              11.2
# 2             AV7         Z                               6.0
# 3             AS6         Z                              12.7
# 4             AS6         Z                              12.1
# ...           ...       ...                               ...
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# 1                                 7.7                               9.6
# 2                                 5.8                               5.9
# 3                                 9.1                              11.1
# 4                                 8.7                              10.6
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                              33                  196
# 1                              29                  221
# 2                              48                  136
# 3                              25                  255
# 4                              27                  244
# ...                           ...                  ...
# 7380                           30                  219
# 7381                           29                  232
# 7382                           27                  240
# 7383                           29                  232
# 7384                           26                  248
#
# [7385 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='str')

# %%
df=df.rename(columns={"Engine Size(L)":"EngSize","CO2 Emissions(g/km)":"Co2Em"})
df.describe()
# Out:
#            EngSize    Cylinders  Fuel Consumption City (L/100 km)  \
# count  7385.000000  7385.000000                       7385.000000
# mean      3.160068     5.615030                         12.556534
# std       1.354170     1.828307                          3.500274
# min       0.900000     3.000000                          4.200000
# 25%       2.000000     4.000000                         10.100000
# 50%       3.000000     6.000000                         12.100000
# 75%       3.700000     6.000000                         14.600000
# max       8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# min                           4.000000                          4.100000
# 25%                           7.500000                          8.900000
# 50%                           8.700000                         10.600000
# 75%                          10.200000                         12.600000
# max                          20.600000                         26.100000
#
#        Fuel Consumption Comb (mpg)        Co2Em
# count                  7385.000000  7385.000000
# mean                     27.481652   250.584699
# std                       7.231879    58.512679
# min                      11.000000    96.000000
# 25%                      22.000000   208.000000
# 50%                      27.000000   246.000000
# 75%                      32.000000   288.000000
# max                      69.000000   522.000000

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=df["EngSize"]
y=df["Co2Em"]
plt.figure(figsize=(8,4))
plt.scatter(x,y,alpha=0.7)
plt.xlabel("ENgine Size")
plt.ylabel("CO2 Emission")
plt.title("Data Points")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
X=df[["EngSize"]]
Y=df["Co2Em"]
model=LinearRegression()
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
print("this is the slope of the best fit line",model.coef_)
print("this is the value of c or intercept",model.intercept_)
# Out:
# this is the slope of the best fit line [36.77731519]
# this is the value of c or intercept 134.3658927234963

# %%
y_pred=model.predict(X)
plt.figure(figsize=(8,4))
plt.scatter(x,y,color="green")#this is creating the scatter plot graph
plt.plot(X,y_pred,color="red")#this is plotting a straight line through the data point
plt.xlabel("ENgine Size")
plt.ylabel("CO2 Emission")
plt.title("Best Fit line")
plt.show()

# %%
y_pred=model.predict(X)
plt.figure(figsize=(8,4))
plt.scatter(x,y_pred,color="green")#this is creating the scatter plot graph
plt.plot(X,y_pred,color="red")#this is plotting a straight line through the data point
plt.xlabel("ENgine Size")
plt.ylabel("CO2 Emission")
plt.title("Best Fit line")
plt.show()

# %%
new_eng=[[2.4]]
pred_val=model.predict(new_eng)
pred_val
# Out:
# c:\Users\ctrkt\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([222.63144917])

# %%
error=Y-y_pred
error.head()
# Out:
# 0   -11.920523
# 1    -1.631449
# 2   -53.531866
# 3    -8.086496
# 4   -19.086496
# Name: Co2Em, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(Y,y_pred)
mse#mean square error and they are also called cost functions
# Out:
# 943.2916297051706

# %%
rmse=np.sqrt(mse)
rmse#root mean square error and they are also called cost functions
# Out:
# np.float64(30.713053083423187)

# %%
gd=-2/len(Y)*np.sum(Y-y_pred)
gd
# Out:
# np.float64(7.438521325265384e-14)

# %%
gdm=(-2/len(X))*np.sum(X.values.flatten()*(Y.values-y_pred))
print("gradient descent of m",gdm)
gdc=(-2/len(X))*np.sum((Y.values-y_pred))
print("Gradient Descent of c is",gdc)
round(gdm,2)
# Out:
# gradient descent of m -1.210853338907438e-12
# Gradient Descent of c is 7.438521325265384e-14
# np.float64(-0.0)

# %%
#m_new=m_old-(lr*gdm) slope update formula
#c_new=c_old-(lr*gdc) intercept update formula

# %% [markdown]
# #### practical approach

# %%
df=pd.read_csv("fueldata.csv")
df=df.rename(columns={"Engine Size(L)":"ES","CO2 Emissions(g/km)":"CO2"})

# %%
X_val=df["ES"].values
Y_val=df["CO2"].values

m=0 # slope 
c=0 # intercept 

lr=0.01 ## learning rate of the model how frequenty it will learn from the data 
epochs=1000# how many times my model will learn from the data

# %%
n=len(X_val)
costhitory=[]
for epoch in range(epochs):
    y_predict=m*X_val+c
    cost=1/n*np.sum(Y_val-y_predict)**2
    gdm=-2/n*np.sum(X_val*(Y_val-y_predict)) ## imp 
    gdc=-2/n*np.sum((Y_val-y_predict)) ### very imp 
    m=m-(lr*gdm)
    c=c-(lr*gdc)
    costhitory.append(cost)

   

print("Slope ",m)
print("Intercept ",c)
print("GDM",gdm)
print("GDC",gdc)
print(costhitory[-1])
# Out:
# Slope  36.872810605525444
# Intercept  134.01308402799728
# GDM 0.027708575211820397
# GDC -0.10236958344311539
# 19.347835242932696
