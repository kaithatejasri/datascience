# %%
import pandas as pd

# %%
df=pd.DataFrame({
    "EngineSize":[1,1.5,2.0,2.5,3.0],
    "Co2":[100,120,140,160,180]
})
df
# Out:
#    EngineSize  Co2
# 0         1.0  100
# 1         1.5  120
# 2         2.0  140
# 3         2.5  160
# 4         3.0  180

# %% [markdown]
# X= input ie the engine size Y= output ie the co2 emmitted by the car
#
# y=mx+c

# %%
m=10
c=50

x=1.0
prediction=m*x+c
prediction
# Out:
# 60.0

# %% [markdown]
# ##### see model predicted 60 and actual is 100
# ##### so the error will be
#
# #100-60=40

# %% [markdown]
# ###### out goal is to derive the formula for the gradient descent (GD) aka J
# ###### yp=y predicted values
# ###### ya= y actual values
# ###### m=slope of line
# ###### c= intercept on y axis
# ###### X ya yp error
# ###### 1 100 0 100
# ###### 2 140 0 140

# %% [markdown]
# m=0 c=0
#
# yp=mx+c for x=1 > yp=01+0 = 0 for x=2 > yp=02+0=0
#
# GD=1/n*(ya-yp)^2 => cost function
#
# GD=1/n*(ya-mx+c)^2 ### we need to minimize this gd value of cost function value

# %% [markdown]
# ##### we will do the partial derivative of gd wrt m
# ##### GD=-2/n{x*(ya-(mx+c))
# ##### gd= -2/n{x*(ya-yp)
# ##### gd=-2/n(np.sum(x(y-y_ypred)))
